# %%
import glob
import pandas as pd
from e2e_system.reproder import _ground_truth
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
from util.file_helper import read_all_csv_files
from util.annotator_helper import form_label_dataframes, get_agreement

# %%
def get_agrmnt(df, metric):
    true_columns = list(_ground_truth)
    pred_columns = [c for c in df.columns if "_pred" in c]
    df["true_score"] = df[true_columns].sum(axis=1)
    df["pred_score"] = df[pred_columns].sum(axis=1)
    if metric == "quadratic":
        aggreement = cohen_kappa_score(
            df.true_score, df.pred_score, weights="quadratic")
    else:
        aggreement = get_agreement(form_label_dataframes(
            df[["true_score", "pred_score"]]), metric)
    return round(aggreement, 3)


def get_correlation(df, round_step=3):
    crr = df.true_reprod_score.corr(other=df.reprod_score)
    return round(crr, round_step)


def analyze_reprod_score(df):
    mean_diff = df.true_reprod_score.mean() - df.reprod_score.mean()
    return round(mean_diff, 3)


def get_evaluation_metric_results(df):
    labelled = df.select_dtypes(include=["bool"])
    pred_columns = [
        column for column in labelled.columns if column.endswith("_pred")]
    true_columns = [
        column for column in labelled.columns if not column.endswith("_pred")]
    pred = labelled[pred_columns].values.flatten()
    true = labelled[true_columns].values.flatten()
    accuracy = accuracy_score(true, pred)
    precision, recall, f1, _ = precision_recall_fscore_support(
        true, pred, average='binary')
    return round(accuracy, 3), round(precision, 3), round(recall, 3), round(f1, 3)


def get_labelling_score(method, selection):
    path = f"data/acl/sections/labelled/{method}/{selection}.csv"
    df = pd.read_csv(path, index_col=0)
    return round(df.score.mean(), 3)

# %%
evaluations = glob.glob(
    "data/paperswithcode/evaluated/classification/bert_base_uncased/neurips/**")

# %%
res = []
for evaluation in evaluations:
    results = read_all_csv_files(f"{evaluation}/")
    for key in results.keys():
        correlation = get_correlation(results[key])
        # kappa = get_agrmnt(results[key], "alpha")
        mean_diff = analyze_reprod_score(results[key])
        accuracy, precision, recall, f1 = get_evaluation_metric_results(
            results[key])
        evaluation = evaluation.split("\\")[-1]
        res.append(
            {
                "correlation": correlation,
                "kappa": get_agrmnt(results[key], "kappa"),
                "weighted_linear": get_agrmnt(results[key], "weighted_kappa"),
                "weighted_quadratic": get_agrmnt(results[key], "quadratic"),
                "fleiss": get_agrmnt(results[key], "multi_kappa"),
                "scott": get_agrmnt(results[key], "pi"),
                "bennett": get_agrmnt(results[key], "S"),
                "alpha": get_agrmnt(results[key], "alpha"),
                "avg_Ao": get_agrmnt(results[key], "avg_Ao"),
     
                # "mean_diff": mean_diff,
                # "accuracy": accuracy,
                # "precision": precision,
                # "recall": recall,
                # "f1": f1,
                "labelling_method": evaluation,
                "type": key.replace("neurips_", ""),
                # "labelling_score": get_labelling_score(evaluation.split("_")[-1], "_".join(evaluation.split("_")[:-1]))
            }
        )

# %%
analysis = pd.DataFrame(res)
analysis["method"] = analysis.labelling_method.str.split("_").str[-1]
analysis["labelling_method"] = analysis.labelling_method.apply(
    lambda x: " ".join(x.split("_")[:-1]))

# %%
# pd.DataFrame(res).set_index(["labelling_method", "type"]).round(3).style.highlight_max(
#     color="green", axis=0).highlight_min(subset=["mean_diff"], color="red", axis=0).format("{:.3f}")
pd.DataFrame(res).set_index(["labelling_method", "type"]).round(3).style.highlight_max(
    color="green", axis=0).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_9a893_row12_col1, #T_9a893_row12_col2, #T_9a893_row12_col3, #T_9a893_row12_col4, #T_9a893_row12_col5, #T_9a893_row12_col6, #T_9a893_row12_col7, #T_9a893_row12_col8, #T_9a893_row13_col0, #T_9a893_row13_col1, #T_9a893_row13_col2, #T_9a893_row13_col3, #T_9a893_row13_col4, #T_9a893_row13_col5, #T_9a893_row13_col6, #T_9a893_row13_col7, #T_9a893_row13_col8 {
#   background-color: green;
# }
# </style>
# <table id="T_9a893">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a893_level0_col0" class="col_heading level0 col0" >correlation</th>
#       <th id="T_9a893_level0_col1" class="col_heading level0 col1" >kappa</th>
#       <th id="T_9a893_level0_col2" class="col_heading level0 col2" >weighted_linear</th>
#       <th id="T_9a893_level0_col3" class="col_heading level0 col3" >weighted_quadratic</th>
#       <th id="T_9a893_level0_col4" class="col_heading level0 col4" >fleiss</th>
#       <th id="T_9a893_level0_col5" class="col_heading level0 col5" >scott</th>
#       <th id="T_9a893_level0_col6" class="col_heading level0 col6" >bennett</th>
#       <th id="T_9a893_level0_col7" class="col_heading level0 col7" >alpha</th>
#       <th id="T_9a893_level0_col8" class="col_heading level0 col8" >avg_Ao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >labelling_method</th>
#       <th class="index_name level1" >type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a893_level0_row0" class="row_heading level0 row0" rowspan="4">content_textsim</th>
#       <th id="T_9a893_level1_row0" class="row_heading level1 row0" >base</th>
#       <td id="T_9a893_row0_col0" class="data row0 col0" >0.549</td>
#       <td id="T_9a893_row0_col1" class="data row0 col1" >0.177</td>
#       <td id="T_9a893_row0_col2" class="data row0 col2" >0.177</td>
#       <td id="T_9a893_row0_col3" class="data row0 col3" >0.521</td>
#       <td id="T_9a893_row0_col4" class="data row0 col4" >0.177</td>
#       <td id="T_9a893_row0_col5" class="data row0 col5" >0.174</td>
#       <td id="T_9a893_row0_col6" class="data row0 col6" >0.232</td>
#       <td id="T_9a893_row0_col7" class="data row0 col7" >0.178</td>
#       <td id="T_9a893_row0_col8" class="data row0 col8" >0.360</td>
#     </tr>
#     <tr>
#       <th id="T_9a893_level1_row1" class="row_heading level1 row1" >consecutive</th>
#       <td id="T_9a893_row1_col0" class="data row1 col0" >0.554</td>
#       <td id="T_9a893_row1_col1" class="data row1 col1" >0.177</td>
#       <td id="T_9a893_row1_col2" class="data row1 col2" >0.177</td>
#       <td id="T_9a893_row1_col3" class="data row1 col3" >0.521</td>
#       <td id="T_9a893_row1_col4" class="data row1 col4" >0.177</td>
#       <td id="T_9a893_row1_col5" class="data row1 col5" >0.174</td>
#       <td id="T_9a893_row1_col6" class="data row1 col6" >0.232</td>
#       <td id="T_9a893_row1_col7" class="data row1 col7" >0.178</td>
#       <td id="T_9a893_row1_col8" class="data row1 col8" >0.360</td>
#     </tr>
#     <tr>
#       <th id="T_9a893_level1_row2" class="row_heading level1 row2" >grouped</th>
#       <td id="T_9a893_row2_col0" class="data row2 col0" >0.376</td>
#       <td id="T_9a893_row2_col1" class="data row2 col1" >0.094</td>
#       <td id="T_9a893_row2_col2" class="data row2 col2" >0.094</td>
#       <td id="T_9a893_row2_col3" class="data row2 col3" >0.337</td>
#       <td id="T_9a893_row2_col4" class="data row2 col4" >0.094</td>
#       <td id="T_9a893_row2_col5" class="data row2 col5" >0.087</td>
#       <td id="T_9a893_row2_col6" class="data row2 col6" >0.148</td>
#       <td id="T_9a893_row2_col7" class="data row2 col7" >0.092</td>
#       <td id="T_9a893_row2_col8" class="data row2 col8" >0.290</td>
#     </tr>
#     <tr>
#       <th id="T_9a893_
td>
#     </tr>
#     <tr>
#       <th id="T_9a893_level1_row7" class="row_heading level1 row7" >grouped_consecutive</th>
#       <td id="T_9a893_row7_col0" class="data row7 col0" >0.434</td>
#       <td id="T_9a893_row7_col1" class="data row7 col1" >0.077</td>
#       <td id="T_9a893_row7_col2" class="data row7 col2" >0.077</td>
#       <td id="T_9a893_row7_col3" class="data row7 col3" >0.371</td>
#       <td id="T_9a893_row7_col4" class="data row7 col4" >0.077</td>
#       <td id="T_9a893_row7_col5" class="data row7 col5" >0.064</td>
#       <td id="T_9a893_row7_col6" class="data row7 col6" >0.124</td>
#       <td id="T_9a893_row7_col7" class="data row7 col7" >0.068</td>
#       <td id="T_9a893_row7_col8" class="data row7 col8" >0.270</td>
#     </tr>
#     <tr>
#       <th id="T_9a893_level0_row8" class="row_heading level0 row8" rowspan="4">grouped_textsim</th>
#       <th id="T_9a893_level1_row8" class="row_heading level1 row8" >base</th>
#       <td id="T_9a893_row8_col0" class="data row8 col0" >0.579</td>

# %%
# pd.DataFrame(res).set_index(["labelling_method", "type"]).sort_values(by=["correlation"], ascending=False).round(3).style.highlight_max(
#     color="green", axis=0).highlight_min(subset=["mean_diff"], color="red", axis=0).format("{:.3f}")
pd.DataFrame(res).set_index(["labelling_method", "type"]).sort_values(by=["correlation"], ascending=False).round(3).style.highlight_max(
    color="green", axis=0).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_31247_row0_col1, #T_31247_row0_col2, #T_31247_row0_col3, #T_31247_row0_col4, #T_31247_row0_col5, #T_31247_row0_col6, #T_31247_row0_col7, #T_31247_row0_col8, #T_31247_row1_col0, #T_31247_row1_col1, #T_31247_row1_col2, #T_31247_row1_col3, #T_31247_row1_col4, #T_31247_row1_col5, #T_31247_row1_col6, #T_31247_row1_col7, #T_31247_row1_col8 {
#   background-color: green;
# }
# </style>
# <table id="T_31247">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31247_level0_col0" class="col_heading level0 col0" >correlation</th>
#       <th id="T_31247_level0_col1" class="col_heading level0 col1" >kappa</th>
#       <th id="T_31247_level0_col2" class="col_heading level0 col2" >weighted_linear</th>
#       <th id="T_31247_level0_col3" class="col_heading level0 col3" >weighted_quadratic</th>
#       <th id="T_31247_level0_col4" class="col_heading level0 col4" >fleiss</th>
#       <th id="T_31247_level0_col5" class="col_heading level0 col5" >scott</th>
#       <th id="T_31247_level0_col6" class="col_heading level0 col6" >bennett</th>
#       <th id="T_31247_level0_col7" class="col_heading level0 col7" >alpha</th>
#       <th id="T_31247_level0_col8" class="col_heading level0 col8" >avg_Ao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >labelling_method</th>
#       <th class="index_name level1" >type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31247_level0_row0" class="row_heading level0 row0" rowspan="2">grouped_zeroshot</th>
#       <th id="T_31247_level1_row0" class="row_heading level1 row0" >base</th>
#       <td id="T_31247_row0_col0" class="data row0 col0" >0.651</td>
#       <td id="T_31247_row0_col1" class="data row0 col1" >0.322</td>
#       <td id="T_31247_row0_col2" class="data row0 col2" >0.322</td>
#       <td id="T_31247_row0_col3" class="data row0 col3" >0.648</td>
#       <td id="T_31247_row0_col4" class="data row0 col4" >0.322</td>
#       <td id="T_31247_row0_col5" class="data row0 col5" >0.318</td>
#       <td id="T_31247_row0_col6" class="data row0 col6" >0.364</td>
#       <td id="T_31247_row0_col7" class="data row0 col7" >0.321</td>
#       <td id="T_31247_row0_col8" class="data row0 col8" >0.470</td>
#     </tr>
#     <tr>
#       <th id="T_31247_
>0.360</td>
#     </tr>
#     <tr>
#       <th id="T_31247_level1_row5" class="row_heading level1 row5" >base</th>
#       <td id="T_31247_row5_col0" class="data row5 col0" >0.578</td>
#       <td id="T_31247_row5_col1" class="data row5 col1" >0.193</td>
#       <td id="T_31247_row5_col2" class="data row5 col2" >0.193</td>
#       <td id="T_31247_row5_col3" class="data row5 col3" >0.523</td>
#       <td id="T_31247_row5_col4" class="data row5 col4" >0.193</td>
#       <td id="T_31247_row5_col5" class="data row5 col5" >0.188</td>
#       <td id="T_31247_row5_col6" class="data row5 col6" >0.232</td>
#       <td id="T_31247_row5_col7" class="data row5 col7" >0.192</td>
#       <td id="T_31247_row5_col8" class="data row5 col8" >0.360</td>
#     </tr>
#     <tr>
#       <th id="T_31247_level0_row6" class="row_heading level0 row6" rowspan="2">content_textsim</th>
#       <th id="T_31247_level1_row6" class="row_heading level1 row6" >base</th>
#       <td id="T_31247_row6_col0" class="data row6 col0" >0.549</td>
#       <td id="T_31247_row6_col1" class="data row6 col1" >0.177</td>
#       <td id="T_31247_row6_col2" class="data row6 col2" >0.177</td>
#       <td id="T_31247_row6_col3" class="data row6 col3" >0.521</td>
#       <td id="T_31247_row6_col4" class="data row6 col4" >0.177</td>
#       <td id="T_31247_row6_col5" class="data row6 col5" >0.174</td>
#       <td id="T_31247_row6_col6" class="data row6 col6" >0.232</td>
#       <td id="T_31247_row6_col7" class="data row6 col7" >0.178</td>
#       <td id="T_31247_row6_col8" class="data row6 col8" >0.360</td>
#     </tr>
#     <tr>
#       <th id="T_31247_level1_row7" class="row_heading level1 row7" >consecutive</th>
#       <td id="T_31247_row7_col0" class="data row7 col0" >0.554</td>
#       <td id="T_31247_row7_col1" class="data row7 col1" >0.177</td>
#       <td id="T_31247_row7_col2" class="data row7 col2" >0.177</td>
#       <td id="T_31247_row7_col3" class="data row7 col3" >0.521</td>
#       <td id="T_31247_row7_col4" class="data row7 col4" >0.177</td>
#       <td id="T_31247_row7_col5" class="data row7 col5" >0.174</td>
#       <td id="T_31247_row7_col6" class="data row7 col6" >0.232</td>
#       <td id="T_31247_row7_col7" class="data row7 col7" >0.178</td>
#       <td id="T_31247_row7_col8" class="data row7 col8" >0.360</td>
#     </tr>
#     <tr>
#       <th id="T_31247_level0_row8" class="row_heading level0 row8" r

# %%
analysis[analysis.type.isin(["grouped", "base"])].groupby(
    "type").mean(numeric_only=True).round(3).reset_index()
# Out:
#       type  correlation  kappa  fleiss  scott  bennett  alpha  weighted_kappa  \
# 0     base        0.571  0.159   0.159  0.154     0.21  0.158           0.159
# 1  grouped        0.396  0.102   0.102  0.095     0.15  0.099           0.102
#
#    quadratic  accuracy
# 0      0.547     0.663
# 1      0.366     0.611

# %%
analysis
0.312
0.30
# Out:
#     correlation  kappa  fleiss  scott  bennett  alpha  weighted_kappa  \
# 0         0.549  0.177   0.177  0.174    0.232  0.178           0.177
# 1         0.554  0.177   0.177  0.174    0.232  0.178           0.177
# 2         0.376  0.094   0.094  0.087    0.148  0.092           0.094
# 3         0.370  0.094   0.094  0.087    0.148  0.092           0.094
# 4         0.582  0.155   0.155  0.152    0.208  0.156           0.155
# 5         0.586  0.155   0.155  0.152    0.208  0.156           0.155
# 6         0.431  0.077   0.077  0.064    0.124  0.068           0.077
# 7         0.434  0.077   0.077  0.064    0.124  0.068           0.077
# 8         0.579  0.145   0.145  0.137    0.196  0.141           0.145
# 9         0.581  0.145   0.145  0.137    0.196  0.141           0.145
# 10        0.410  0.120   0.120  0.113    0.172  0.118           0.120
# 11        0.412  0.120   0.120  0.113    0.172  0.118           0.120
# 12        0.651  0.322   0.322  0.318    0.364  0.321           0.322
# 13        0.661  0.322   0.322  0.318    0.364  0.321           0.322
# 14        0.382  0.153   0.153  0.146    0.196  0.150           0.153
# 15        0.386  0.153   0.153  0.146    0.196  0.150           0.153
# 16        0.578  0.193   0.193  0.188    0.232  0.192           0.193
# 17        0.571  0.193   0.193  0.188    0.232  0.192           0.193
# 18        0.397  0.147   0.147  0.141    0.196  0.145           0.147
# 19        0.391  0.147   0.147  0.141    0.196  0.145           0.147
# 20        0.631  0.157   0.157  0.154    0.208  0.158           0.157
# 21        0.626  0.157   0.157  0.154    0.208  0.158           0.157
# 22        0.394  0.081   0.081  0.073    0.124  0.078           0.081
# 23        0.394  0.081   0.081  0.073    0.124  0.078           0.081
# 24        0.568  0.145   0.145  0.140    0.196  0.144           0.145
# 25        0.569  0.145   0.145  0.140    0.196  0.144           0.145
# 26        0.417  0.162   0.162  0.158    0.208  0.163           0.162
# 27        0.414  0.162   0.162  0.158    0.208  0.163           0.162
# 28        0.617  0.204   0.204  0.198    0.244  0.202           0.204
# 29        0.624  0.204   0.204  0.198    0.244  0.202           0.204
# 30        0.369  0.078   0.078  0.070    0.124  0.075           0.078
# 31        0.370  0.078   0.078  0.070    0.124  0.075           0.078
# 32        0.602  0.102   0.102  0.095    0.160  0.100           0.102
# 33        0.597  0.102   0.102  0.095    0.160  0.100           0.102
# 34        0.403  0.075   0.075  0.067    0.124  0.072           0.075
# 35        0.403  0.075   0.075  0.067    0.124  0.072           0.075
# 36        0.594  0.074   0.074  0.071    0.136  0.075           0.074
# 37        0.587  0.074   0.074  0.071    0.136  0.075           0.074
# 38        0.421  0.072   0.072  0.065    0.124  0.070           0.072
# 39        0.419  0.072   0.072  0.065    0.124  0.070           0.072
# 40        0.497  0.099   0.099  0.089    0.160  0.094           0.099
# 41        0.473  0.099   0.099  0.089    0.160  0.094           0.099
# 42        0.395  0.054   0.054  0.043    0.100  0.047           0.054
# 43        0.377  0.054   0.054  0.043    0.100  0.047           0.054
# 44        0.399  0.130   0.130  0.128    0.184  0.132           0.130
# 45        0.383  0.130   0.130  0.128    0.184  0.132           0.130
# 46        0.358  0.114   0.114  0.109    0.160  0.114           0.114
# 47        0.353  0.114   0.114  0.109    0.160  0.114           0.114
#
#     quadratic  accuracy     labelling_method                 type    method
# 0       0.521     0.665              content                 base   textsim
# 1       0.521     0.665              content          consecutive   textsim
# 2       0.337     0.602              content              grouped   textsim
# 3       0.337     0.602              content  grouped_consecutive   textsim
# 4       0.563     0.662              content                 base  zeroshot
# 5       0.563     0.662              content          consecutive  zeroshot
# 6       0.371     0.610              content              grouped  zeroshot
# 7       0.371     0.610              content  grouped_consecutive  zeroshot
# 8       0.542     0.697              grouped                 base   textsim
# 9       0.542     0.697              grouped          consecutive   textsim
# 10      0.382     0.615              grouped              grouped   textsim
# 11      0.382     0.615              grouped  grouped_consecutive   textsim
# 12      0.648     0.697              grouped                 base  zeroshot
# 13      0.648     0.697              grouped          consecutive  zeroshot
# 14      0.399     0.647              grouped              grouped  zeroshot
# 15      0.399     0.647              grouped  grouped_consecutive  zeroshot
# 16      0.523     0.685       header content                 base   textsim
# 17      0.523     0.685       header content          consecutive   textsim
# 18      0.320     0.607       header content              grouped   textsim
# 19      0.320     0.607       header content  grouped_consecutive   textsim
# 20      0.631     0.665       header content                 base  zeroshot
# 21      0.631     0.665       header content          consecutive  zeroshot
# 22      0.426     0.623       header content              grouped  zeroshot
# 23      0.426     0.623       header content  grouped_consecutive  zeroshot
# 24      0.528     0.692  header plus content                 base   textsim
# 25      0.528     0.692  header plus content          consecutive   textsim
# 26      0.374     0.630  header plus content              grouped   textsim
# 27      0.374     0.630  header plus content  grouped_consecutive   textsim
# 28      0.556     0.698  header plus content                 base  zeroshot
# 29      0.556     0.698  header plus content          consecutive  zeroshot
# 30      0.340     0.647  header plus content              grouped  zeroshot
# 31      0.340     0.647  header plus content  grouped_consecutive  zeroshot
# 32      0.613     0.668          header plus                 base   textsim
# 33      0.613     0.668          header plus          consecutive   textsim
# 34      0.357     0.607          header plus              grouped   textsim
# 35      0.357     0.607          header plus  grouped_consecutive   textsim
# 36      0.540     0.608          header plus                 base  zeroshot
# 37      0.540     0.608          header plus          consecutive  zeroshot
# 38      0.373     0.572          header plus              grouped  zeroshot
# 39      0.373     0.572          header plus  grouped_consecutive  zeroshot
# 40      0.479     0.637               header                 base   textsim
# 41      0.479     0.637               header          consecutive   textsim
# 42      0.343     0.612               header              grouped   textsim
# 43      0.343     0.612               header  grouped_consecutive   textsim
# 44      0.419     0.587               header                 base  zeroshot
# 45      0.419     0.587               header          consecutive  zeroshot
# 46      0.364     0.563               header              grouped  zeroshot
# 47      0.364     0.563               header  grouped_consecutive  zeroshot

# %%
analysis.groupby(["method", "labelling_method"]).mean(numeric_only=True).round(
    3)
# Out:
#                               correlation  kappa  fleiss  scott  bennett  \
# method   labelling_method
# textsim  content                    0.462  0.136   0.136  0.130    0.190
#          grouped                    0.495  0.132   0.132  0.125    0.184
#          header                     0.436  0.076   0.076  0.066    0.130
#          header content             0.484  0.170   0.170  0.164    0.214
#          header plus                0.501  0.088   0.088  0.081    0.142
#          header plus content        0.492  0.154   0.154  0.149    0.202
# zeroshot content                    0.508  0.116   0.116  0.108    0.166
#          grouped                    0.520  0.238   0.238  0.232    0.280
#          header                     0.373  0.122   0.122  0.118    0.172
#          header content             0.511  0.119   0.119  0.113    0.166
#          header plus                0.505  0.073   0.073  0.068    0.130
#          header plus content        0.495  0.141   0.141  0.134    0.184
#
#                               alpha  weighted_kappa  quadratic  accuracy
# method   labelling_method
# textsim  content              0.135           0.136      0.429     0.634
#          grouped              0.130           0.132      0.462     0.656
#          header               0.070           0.076      0.411     0.624
#          header content       0.168           0.170      0.422     0.646
#          header plus          0.086           0.088      0.485     0.638
#          header plus content  0.154           0.154      0.451     0.661
# zeroshot content              0.112           0.116      0.467     0.636
#          grouped              0.236           0.238      0.524     0.672
#          header               0.123           0.122      0.391     0.575
#          header content       0.118           0.119      0.528     0.644
#          header plus          0.073           0.073      0.456     0.590
#          header plus content  0.138           0.141      0.448     0.672
