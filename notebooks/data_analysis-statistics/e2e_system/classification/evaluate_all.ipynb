# %%
import glob
import pandas as pd
from e2e_system.reproder import _ground_truth
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
from util.file_helper import read_all_csv_files

# %%
def get_kappa(df):
    true_columns = list(_ground_truth)
    pred_columns = [c for c in df.columns if "_pred" in c]
    df["true_score"] = df[true_columns].sum(axis=1)
    df["pred_score"] = df[pred_columns].sum(axis=1)

    return round(cohen_kappa_score(df.true_score, df.pred_score, weights="quadratic"), 3)


def get_correlation(df, round_step=3):
    crr = df.true_reprod_score.corr(other=df.reprod_score)
    return round(crr, round_step)


def analyze_reprod_score(df):
    mean_diff = df.true_reprod_score.mean() - df.reprod_score.mean()
    return round(mean_diff, 3)


def get_evaluation_metric_results(df):
    labelled = df.select_dtypes(include=["bool"])
    pred_columns = [
        column for column in labelled.columns if column.endswith("_pred")]
    true_columns = [
        column for column in labelled.columns if not column.endswith("_pred")]
    pred = labelled[pred_columns].values.flatten()
    true = labelled[true_columns].values.flatten()
    accuracy = accuracy_score(true, pred)
    precision, recall, f1, _ = precision_recall_fscore_support(
        true, pred, average='binary')
    return round(accuracy, 3), round(precision, 3), round(recall, 3), round(f1, 3)


def get_labelling_score(method, selection):
    path = f"data/acl/sections/labelled/{method}/{selection}.csv"
    df = pd.read_csv(path, index_col=0)
    return round(df.score.mean(), 3)

# %%
evaluations = glob.glob(
    "data/paperswithcode/evaluated/classification/bert_base_uncased/neurips/**")

# %%
res = []
for evaluation in evaluations:
    results = read_all_csv_files(f"{evaluation}/")
    for key in results.keys():
        correlation = get_correlation(results[key])
        kappa = get_kappa(results[key])
        mean_diff = analyze_reprod_score(results[key])
        accuracy, precision, recall, f1 = get_evaluation_metric_results(
            results[key])
        evaluation = evaluation.split("\\")[-1]
        res.append(
            {
                "correlation": correlation,
                "kappa": kappa,
                # "mean_diff": mean_diff,
                "accuracy": accuracy,
                # "precision": precision,
                # "recall": recall,
                # "f1": f1,
                "labelling_method": evaluation,
                "type": key.replace("neurips_", ""),
                # "labelling_score": get_labelling_score(evaluation.split("_")[-1], "_".join(evaluation.split("_")[:-1]))
            }
        )

# %%
analysis = pd.DataFrame(res)
analysis["method"] = analysis.labelling_method.str.split("_").str[-1]
analysis["labelling_method"] = analysis.labelling_method.apply(
    lambda x: " ".join(x.split("_")[:-1]))

# %%
# pd.DataFrame(res).set_index(["labelling_method", "type"]).round(3).style.highlight_max(
#     color="green", axis=0).highlight_min(subset=["mean_diff"], color="red", axis=0).format("{:.3f}")
x = pd.DataFrame(res).set_index(["labelling_method", "type"]).reset_index().round(3)
x["method"] = x.labelling_method.str.split("_").str[-1]
x.sort_values(by=["method", "labelling_method"]).set_index(["method", "labelling_method", "type"]).round(3).style.highlight_min(
    color="green", axis=0).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_1368a_row10_col1, #T_1368a_row11_col1, #T_1368a_row46_col2, #T_1368a_row47_col0, #T_1368a_row47_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_1368a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1368a_level0_col0" class="col_heading level0 col0" >correlation</th>
#       <th id="T_1368a_level0_col1" class="col_heading level0 col1" >kappa</th>
#       <th id="T_1368a_level0_col2" class="col_heading level0 col2" >accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th class="index_name level1" >labelling_method</th>
#       <th class="index_name level2" >type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1368a_level0_row0" class="row_heading level0 row0" rowspan="24">textsim</th>
#       <th id="T_1368a_level1_row0" class="row_heading level1 row0" rowspan="4">content_textsim</th>
#       <th id="T_1368a_level2_row0" class="row_heading level2 row0" >base</th>
#       <td id="T_1368a_row0_col0" class="data row0 col0" >0.549</td>
#       <td id="T_1368a_row0_col1" class="data row0 col1" >0.521</td>
#       <td id="T_1368a_row0_col2" class="data row0 col2" >0.665</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row1" class="row_heading level2 row1" >consecutive</th>
#       <td id="T_1368a_row1_col0" class="data row1 col0" >0.554</td>
#       <td id="T_1368a_row1_col1" class="data row1 col1" >0.521</td>
#       <td id="T_1368a_row1_col2" class="data row1 col2" >0.665</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row2" class="row_heading level2 row2" >grouped</th>
#       <td id="T_1368a_row2_col0" class="data row2 col0" >0.376</td>
#       <td id="T_1368a_row2_col1" class="data row2 col1" >0.337</td>
#       <td id="T_1368a_row2_col2" class="data row2 col2" >0.602</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row3" class="row_heading level2 row3" >grouped_consecutive</th>
#       <td id="T_1368a_row3_col0" class="data row3 col0" >0.370</td>
#       <td id="T_1368a_row3_col1" class="data row3 col1" >0.337</td>
#       <td id="T_1368a_row3_col2" class="data row3 col2" >0.602</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level1_row4" class="row_heading level1 row4" rowspan="4">grouped_textsim</th>
#       <th id="T_1368a_level2_row4" class="row_heading level2 row4" >base</th>
#       <td id="T_1368a_row4_col0" class="data row4 col0" >0.579</td>
#       <td id="T_1368a_row4_col1" class="data row4 col1" >0.542</td>
#       <td id="T_1368a_row4_col2" class="data row4 col2" >0.697</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row5" class="row_heading level2 row5" >consecutive</th>
#       <td id="T_1368a_row5_col0" class="data row5 col0" >0.581</td>
#       <td id="T_1368a_row5_col1" class="data row5 col1" >0.542</td>
#       <td id="T_1368a_row5_col2" class="data row5 col2" >0.697</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row6" class="row_heading level2 row6" >grouped</th>
#       <td id="T_1368a_row6_col0" class="data row6 col0" >0.410</td>
#       <td id="T_1368a_row6_col1" class="data row6 col1" >0.382</td>
#       <td id="T_1368a_row6_col2" class="data row6 col2" >0.615</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row7" class="row_heading level2 row7" >grouped_consecutive</th>
#       <td id="T_1368a_row7_col0" class="data row7 col0" >0.412</td>
#       <td id="T_1368a_row7_col1" class="data row7 col1" >0.382</td>
#       <td id="T_1368a_row7_col2" class="data row7 col2" >0.615</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level1_row8" class="row_heading level1 row8" rowspan="4">header_content_textsim</th>
#       <th id="T_1368a_level2_row8" class="row_heading level2 row8" >base</th>
#       <td id="T_1368a_row8_col0" class="data row8 col0" >0.578</td>
#       <td id="T_1368a_row8_col1" class="data row8 col1" >0.523</td>
#       <td id="T_1368a_row8_col2" class="data row8 col2" >0.685</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row9" class="row_heading level2 row9" >consecutive</th>
#       <td id="T_1368a_row9_col0" class="data row9 col0" >0.571</td>
#       <td id="T_1368a_row9_col1" class="data row9 col1" >0.523</td>
#       <td id="T_1368a_row9_col2" class="data row9 col2" >0.685</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row10" class="row_heading level2 row10" >grouped</th>
#       <td id="T_1368a_row10_col0" class="data row10 col0" >0.397</td>
#       <td id="T_1368a_row10_col1" class="data row10 col1" >0.320</td>
#       <td id="T_1368a_row10_col2" class="data row10 col2" >0.607</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row11" class="row_heading level2 row11" >grouped_consecutive</th>
#       <td id="T_1368a_row11_col0" class="data row11 col0" >0.391</td>
#       <td id="T_1368a_row11_col1" class="data row11 col1" >0.320</td>
#       <td id="T_1368a_row11_col2" class="data row11 col2" >0.607</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level1_row12" class="row_heading level1 row12" rowspan="4">header_plus_content_textsim</th>
#       <th id="T_1368a_level2_row12" class="row_heading level2 row12" >base</th>
#       <td id="T_1368a_row12_col0" class="data row12 col0" >0.568</td>
#       <td id="T_1368a_row12_col1" class="data row12 col1" >0.528</td>
#       <td id="T_1368a_row12_col2" class="data row12 col2" >0.692</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row13" class="row_heading level2 row13" >consecutive</th>
#       <td id="T_1368a_row13_col0" class="data row13 col0" >0.569</td>
#       <td id="T_1368a_row13_col1" class="data row13 col1" >0.528</td>
#       <td id="T_1368a_row13_col2" class="data row13 col2" >0.692</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row14" class="row_heading level2 row14" >grouped</th>
#       <td id="T_1368a_row14_col0" class="data row14 col0" >0.417</td>
#       <td id="T_1368a_row14_col1" class="data row14 col1" >0.374</td>
#       <td id="T_1368a_row14_col2" class="data row14 col2" >0.630</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row15" class="row_heading level2 row15" >grouped_consecutive</th>
#       <td id="T_1368a_row15_col0" class="data row15 col0" >0.414</td>
#       <td id="T_1368a_row15_col1" class="data row15 col1" >0.374</td>
#       <td id="T_1368a_row15_col2" class="data row15 col2" >0.630</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level1_row16" class="row_heading level1 row16" rowspan="4">header_plus_textsim</th>
#       <th id="T_1368a_level2_row16" class="row_heading level2 row16" >base</th>
#       <td id="T_1368a_row16_col0" class="data row16 col0" >0.602</td>
#       <td id="T_1368a_row16_col1" class="data row16 col1" >0.613</td>
#       <td id="T_1368a_row16_col2" class="data row16 col2" >0.668</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row17" class="row_heading level2 row17" >consecutive</th>
#       <td id="T_1368a_row17_col0" class="data row17 col0" >0.597</td>
#       <td id="T_1368a_row17_col1" class="data row17 col1" >0.613</td>
#       <td id="T_1368a_row17_col2" class="data row17 col2" >0.668</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row18" class="row_heading level2 row18" >grouped</th>
#       <td id="T_1368a_row18_col0" class="data row18 col0" >0.403</td>
#       <td id="T_1368a_row18_col1" class="data row18 col1" >0.357</td>
#       <td id="T_1368a_row18_col2" class="data row18 col2" >0.607</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level2_row19" class="row_heading level2 row19" >grouped_consecutive</th>
#       <td id="T_1368a_row19_col0" class="data row19 col0" >0.403</td>
#       <td id="T_1368a_row19_col1" class="data row19 col1" >0.357</td>
#       <td id="T_1368a_row19_col2" class="data row19 col2" >0.607</td>
#     </tr>
#     <tr>
#       <th id="T_1368a_level1_row20" class="row_heading level1 row20" rowspan="4">header_textsim</th>
#       <th id="T_1368a_level2_row20" class="row_heading level2 row20" >base</th>
#       <td id="T_1368a_row20_col0" class="data row20 col0" >0.4

# %%
# pd.DataFrame(res).set_index(["labelling_method", "type"]).sort_values(by=["correlation"], ascending=False).round(3).style.highlight_max(
#     color="green", axis=0).highlight_min(subset=["mean_diff"], color="red", axis=0).format("{:.3f}")

pd.DataFrame(res).set_index(["labelling_method", "type"]).sort_values(by=["correlation"], ascending=False).round(3).style.highlight_max(
    color="green", axis=0).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_26a2e_row0_col0, #T_26a2e_row0_col1, #T_26a2e_row1_col1, #T_26a2e_row4_col2, #T_26a2e_row5_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_26a2e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26a2e_level0_col0" class="col_heading level0 col0" >correlation</th>
#       <th id="T_26a2e_level0_col1" class="col_heading level0 col1" >kappa</th>
#       <th id="T_26a2e_level0_col2" class="col_heading level0 col2" >accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >labelling_method</th>
#       <th class="index_name level1" >type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26a2e_level0_row0" class="row_heading level0 row0" rowspan="2">grouped_zeroshot</th>
#       <th id="T_26a2e_level1_row0" class="row_heading level1 row0" >consecutive</th>
#       <td id="T_26a2e_row0_col0" class="data row0 col0" >0.661</td>
#       <td id="T_26a2e_row0_col1" class="data row0 col1" >0.648</td>
#       <td id="T_26a2e_row0_col2" class="data row0 col2" >0.697</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row1" class="row_heading level1 row1" >base</th>
#       <td id="T_26a2e_row1_col0" class="data row1 col0" >0.651</td>
#       <td id="T_26a2e_row1_col1" class="data row1 col1" >0.648</td>
#       <td id="T_26a2e_row1_col2" class="data row1 col2" >0.697</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level0_row2" class="row_heading level0 row2" rowspan="2">header_content_zeroshot</th>
#       <th id="T_26a2e_level1_row2" class="row_heading level1 row2" >base</th>
#       <td id="T_26a2e_row2_col0" class="data row2 col0" >0.631</td>
#       <td id="T_26a2e_row2_col1" class="data row2 col1" >0.631</td>
#       <td id="T_26a2e_row2_col2" class="data row2 col2" >0.665</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row3" class="row_heading level1 row3" >consecutive</th>
#       <td id="T_26a2e_row3_col0" class="data row3 col0" >0.626</td>
#       <td id="T_26a2e_row3_col1" class="data row3 col1" >0.631</td>
#       <td id="T_26a2e_row3_col2" class="data row3 col2" >0.665</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level0_row4" class="row_heading level0 row4" rowspan="2">header_plus_content_zeroshot</th>
#       <th id="T_26a2e_level1_row4" class="row_heading level1 row4" >consecutive</th>
#       <td id="T_26a2e_row4_col0" class="data row4 col0" >0.624</td>
#       <td id="T_26a2e_row4_col1" class="data row4 col1" >0.556</td>
#       <td id="T_26a2e_row4_col2" class="data row4 col2" >0.698</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row5" class="row_heading level1 row5" >base</th>
#       <td id="T_26a2e_row5_col0" class="data row5 col0" >0.617</td>
#       <td id="T_26a2e_row5_col1" class="data row5 col1" >0.556</td>
#       <td id="T_26a2e_row5_col2" class="data row5 col2" >0.698</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level0_row6" class="row_heading level0 row6" rowspan="2">header_plus_textsim</th>
#       <th id="T_26a2e_level1_row6" class="row_heading level1 row6" >base</th>
#       <td id="T_26a2e_row6_col0" class="data row6 col0" >0.602</td>
#       <td id="T_26a2e_row6_col1" class="data row6 col1" >0.613</td>
#       <td id="T_26a2e_row6_col2" class="data row6 col2" >0.668</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row7" class="row_heading level1 row7" >consecutive</th>
#       <td id="T_26a2e_row7_col0" class="data row7 col0" >0.597</td>
#       <td id="T_26a2e_row7_col1" class="data row7 col1" >0.613</td>
#       <td id="T_26a2e_row7_col2" class="data row7 col2" >0.668</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level0_row8" class="row_heading level0 row8" rowspan="2">header_plus_zeroshot</th>
#       <th id="T_26a2e_level1_row8" class="row_heading level1 row8" >base</th>
#       <td id="T_26a2e_row8_col0" class="data row8 col0" >0.594</td>
#       <td id="T_26a2e_row8_col1" class="data row8 col1" >0.540</td>
#       <td id="T_26a2e_row8_col2" class="data row8 col2" >0.608</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row9" class="row_heading level1 row9" >consecutive</th>
#       <td id="T_26a2e_row9_col0" class="data row9 col0" >0.587</td>
#       <td id="T_26a2e_row9_col1" class="data row9 col1" >0.540</td>
#       <td id="T_26a2e_row9_col2" class="data row9 col2" >0.608</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level0_row10" class="row_heading level0 row10" rowspan="2">content_zeroshot</th>
#       <th id="T_26a2e_level1_row10" class="row_heading level1 row10" >consecutive</th>
#       <td id="T_26a2e_row10_col0" class="data row10 col0" >0.586</td>
#       <td id="T_26a2e_row10_col1" class="data row10 col1" >0.563</td>
#       <td id="T_26a2e_row10_col2" class="data row10 col2" >0.662</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row11" class="row_heading level1 row11" >base</th>
#       <td id="T_26a2e_row11_col0" class="data row11 col0" >0.582</td>
#       <td id="T_26a2e_row11_col1" class="data row11 col1" >0.563</td>
#       <td id="T_26a2e_row11_col2" class="data row11 col2" >0.662</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level0_row12" class="row_heading level0 row12" rowspan="2">grouped_textsim</th>
#       <th id="T_26a2e_level1_row12" class="row_heading level1 row12" >consecutive</th>
#       <td id="T_26a2e_row12_col0" class="data row12 col0" >0.581</td>
#       <td id="T_26a2e_row12_col1" class="data row12 col1" >0.542</td>
#       <td id="T_26a2e_row12_col2" class="data row12 col2" >0.697</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row13" class="row_heading level1 row13" >base</th>
#       <td id="T_26a2e_row13_col0" class="data row13 col0" >0.579</td>
#       <td id="T_26a2e_row13_col1" class="data row13 col1" >0.542</td>
#       <td id="T_26a2e_row13_col2" class="data row13 col2" >0.697</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level0_row14" class="row_heading level0 row14" rowspan="2">header_content_textsim</th>
#       <th id="T_26a2e_level1_row14" class="row_heading level1 row14" >base</th>
#       <td id="T_26a2e_row14_col0" class="data row14 col0" >0.578</td>
#       <td id="T_26a2e_row14_col1" class="data row14 col1" >0.523</td>
#       <td id="T_26a2e_row14_col2" class="data row14 col2" >0.685</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row15" class="row_heading level1 row15" >consecutive</th>
#       <td id="T_26a2e_row15_col0" class="data row15 col0" >0.571</td>
#       <td id="T_26a2e_row15_col1" class="data row15 col1" >0.523</td>
#       <td id="T_26a2e_row15_col2" class="data row15 col2" >0.685</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level0_row16" class="row_heading level0 row16" rowspan="2">header_plus_content_textsim</th>
#       <th id="T_26a2e_level1_row16" class="row_heading level1 row16" >consecutive</th>
#       <td id="T_26a2e_row16_col0" class="data row16 col0" >0.569</td>
#       <td id="T_26a2e_row16_col1" class="data row16 col1" >0.528</td>
#       <td id="T_26a2e_row16_col2" class="data row16 col2" >0.692</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row17" class="row_heading level1 row17" >base</th>
#       <td id="T_26a2e_row17_col0" class="data row17 col0" >0.568</td>
#       <td id="T_26a2e_row17_col1" class="data row17 col1" >0.528</td>
#       <td id="T_26a2e_row17_col2" class="data row17 col2" >0.692</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level0_row18" class="row_heading level0 row18" rowspan="2">content_textsim</th>
#       <th id="T_26a2e_level1_row18" class="row_heading level1 row18" >consecutive</th>
#       <td id="T_26a2e_row18_col0" class="data row18 col0" >0.554</td>
#       <td id="T_26a2e_row18_col1" class="data row18 col1" >0.521</td>
#       <td id="T_26a2e_row18_col2" class="data row18 col2" >0.665</td>
#     </tr>
#     <tr>
#       <th id="T_26a2e_level1_row19" class="row_heading level1 row19" >base</th>
#       <td id="T_26a2e_row19_col0" class="data row19 col0" >0.549</td>
#       <td id="T_26a2e_row19_col1" class="data row19 col1" >0.521</td>
#       <td id="T_26a2e_row19_col2" cla

# %%
analysis["consecutive"] = analysis.type.apply(
    lambda x: "consecutive" if "consecutive" in x else "non-consecutive")

# %%
analysis.groupby(["method", "labelling_method"]).mean(
    numeric_only=True).round(3)
# Out:
#                               correlation  kappa  accuracy
# method   labelling_method
# textsim  content                    0.462  0.429     0.634
#          grouped                    0.495  0.462     0.656
#          header                     0.436  0.411     0.624
#          header content             0.484  0.422     0.646
#          header plus                0.501  0.485     0.638
#          header plus content        0.492  0.451     0.661
# zeroshot content                    0.508  0.467     0.636
#          grouped                    0.520  0.524     0.672
#          header                     0.373  0.391     0.575
#          header content             0.511  0.528     0.644
#          header plus                0.505  0.456     0.590
#          header plus content        0.495  0.448     0.672

# %%
analysis[analysis.type.isin(["grouped", "base"])].groupby(
    "type").mean(numeric_only=True).round(3).reset_index()
# Out:
#       type  correlation  kappa  accuracy
# 0     base        0.571  0.547     0.663
# 1  grouped        0.396  0.366     0.611

# %%
analysis.groupby(["method"]).mean(
    numeric_only=True).round(3).reset_index()
# Out:
#      method  correlation  kappa  accuracy
# 0   textsim        0.478  0.443     0.643
# 1  zeroshot        0.486  0.469     0.632

# %%
analysis.groupby(["type"]).mean(numeric_only=True).round(3).reset_index()
# Out:
#                   type  correlation  kappa  accuracy
# 0                 base        0.571  0.547     0.663
# 1          consecutive        0.568  0.547     0.663
# 2              grouped        0.396  0.366     0.611
# 3  grouped_consecutive        0.394  0.366     0.611

# %%
analysis.groupby("labelling_method").mean( 
    numeric_only=True).round(3).style.highlight_max(color="green", axis=0).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_d8ed1_row1_col0, #T_d8ed1_row1_col1, #T_d8ed1_row5_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_d8ed1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8ed1_level0_col0" class="col_heading level0 col0" >correlation</th>
#       <th id="T_d8ed1_level0_col1" class="col_heading level0 col1" >kappa</th>
#       <th id="T_d8ed1_level0_col2" class="col_heading level0 col2" >accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >labelling_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8ed1_level0_row0" class="row_heading level0 row0" >content</th>
#       <td id="T_d8ed1_row0_col0" class="data row0 col0" >0.485</td>
#       <td id="T_d8ed1_row0_col1" class="data row0 col1" >0.448</td>
#       <td id="T_d8ed1_row0_col2" class="data row0 col2" >0.635</td>
#     </tr>
#     <tr>
#       <th id="T_d8ed1_level0_row1" class="row_heading level0 row1" >grouped</th>
#       <td id="T_d8ed1_row1_col0" class="data row1 col0" >0.508</td>
#       <td id="T_d8ed1_row1_col1" class="data row1 col1" >0.493</td>
#       <td id="T_d8ed1_row1_col2" class="data row1 col2" >0.664</td>
#     </tr>
#     <tr>
#       <th id="T_d8ed1_level0_row2" class="row_heading level0 row2" >header</th>
#       <td id="T_d8ed1_row2_col0" class="data row2 col0" >0.404</td>
#       <td id="T_d8ed1_row2_col1" class="data row2 col1" >0.401</td>
#       <td id="T_d8ed1_row2_col2" class="data row2 col2" >0.600</td>
#     </tr>
#     <tr>
#       <th id="T_d8ed1_level0_row3" class="row_heading level0 row3" >header content</th>
#       <td id="T_d8ed1_row3_col0" class="data row3 col0" >0.498</td>
#       <td id="T_d8ed1_row3_col1" class="data row3 col1" >0.475</td>
#       <td id="T_d8ed1_row3_col2" class="data row3 col2" >0.645</td>
#     </tr>
#     <tr>
#       <th id="T_d8ed1_level0_row4" class="row_heading level0 row4" >header plus</th>
#       <td id="T_d8ed1_row4_col0" class="data row4 col0" >0.503</td>
#       <td id="T_d8ed1_row4_col1" class="data row4 col1" >0.471</td>
#       <td id="T_d8ed1_row4_col2" class="data row4 col2" >0.614</td>
#     </tr>
#     <tr>
#       <th id="T_d8ed1_level0_row5" class="row_heading level0 row5" >header plus content</th>
#       <td id="T_d8ed1_row5_col0" class="data row5 col0" >0.494</td>
#       <td id="T_d8ed1_row5_col1" class="data row5 col1" >0.450</td>
#       <td id="T_d8ed1_row5_col2" class="data row5 col2" >0.667</td>
#     </tr>
#   </tbody>
# </table>

# %%
analysis[(analysis.type.isin(["base"])) & (
    analysis.labelling_method.isin(["header plus content"]))]
# Out:
#     correlation  kappa  accuracy     labelling_method  type    method  \
# 24        0.568  0.528     0.692  header plus content  base   textsim
# 28        0.617  0.556     0.698  header plus content  base  zeroshot
#
#         consecutive
# 24  non-consecutive
# 28  non-consecutive
